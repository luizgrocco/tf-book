# %% [markdown]
# # Introductory CNN Model: MNIST Digits
#
# ----------------------------------
#
# In this example, we will download the MNIST handwritten digits and create a simple CNN network based on LeNet-5 to predict the digit category (0-9).
#
# To start, we load the necessary libraries.

# %%
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf

# %% [markdown]
# Keras has a built in method for loading the MNIST data sets.

# %%
# Load data
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()

# %%
x_train = x_train.reshape(-1, 28, 28, 1)
x_test = x_test.reshape(-1, 28, 28, 1)

#Padding the images by 2 pixels since in the paper input images were 32x32
# x_train = np.pad(x_train, ((0,0),(2,2),(2,2),(0,0)), 'constant')
# x_test = np.pad(x_test, ((0,0),(2,2),(2,2),(0,0)), 'constant')

# %%
x_train = x_train / 255
x_test = x_test/ 255

# %% [markdown]
# Now, we set the model parameters as follows.

# %%
## Set model parameters
image_width = x_train[0].shape[0]
image_height = x_train[0].shape[1]
num_channels = 1 # grayscale = 1 channel

# training and test data variables
batch_size = 100
evaluation_size = 500
epochs = 1000
eval_every = 5

# set for reproducible results
seed = 98
np.random.seed(seed)
tf.random.set_seed(seed)

# %% [markdown]
# Here we declare our model.
# We will have the feature extractor module composed of two convolutional/relu/max pooling layers followed by the classifier with fully connected layers.

# %%
input_data = tf.keras.Input(dtype=tf.float32, shape=(image_width,image_height, num_channels), name="INPUT")

# First Conv-ReLU-MaxPool Layer
conv1 = tf.keras.layers.Conv2D(filters=6,
                               kernel_size=5,
                               padding='VALID',
                               activation="relu",
                               name="C1")(input_data)

max_pool1 = tf.keras.layers.MaxPool2D(pool_size=2,
                                      strides=2, 
                                      padding='SAME',
                                      name="S1")(conv1)

# Second Conv-ReLU-MaxPool Layer
conv2 = tf.keras.layers.Conv2D(filters=16,
                               kernel_size=5,
                               padding='VALID',
                               strides=1,
                               activation="relu",
                               name="C3")(max_pool1)

max_pool2 = tf.keras.layers.MaxPool2D(pool_size=2,
                                      strides=2, 
                                      padding='SAME',
                                      name="S4")(conv2)

# Flatten Layer
flatten = tf.keras.layers.Flatten(name="FLATTEN")(max_pool2)


# First Fully Connected Layer
fully_connected1 = tf.keras.layers.Dense(units=120,
                                         activation="relu",
                                         name="F5")(flatten)

# Second Fully Connected Layer
fully_connected2 = tf.keras.layers.Dense(units=84,
                                         activation="relu",
                                         name="F6")(fully_connected1)

# Final Fully Connected Layer
final_model_output = tf.keras.layers.Dense(units=10,
                                           activation="softmax",
                                           name="OUTPUT"
                                           )(fully_connected2)
    

model = tf.keras.Model(inputs= input_data, outputs=final_model_output)
# Out:
# 2022-02-22 01:14:36.625550: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2022-02-22 01:14:36.652955: E tensorflow/stream_executor/cuda/cuda_driver.cc:313] failed call to cuInit: UNKNOWN ERROR (100)
# 2022-02-22 01:14:36.652994: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (LuizGustavo-PC): /proc/driver/nvidia/version does not exist
# 2022-02-22 01:14:36.654080: I tensorflow/core/platform/cpu_feature_guard.cc:143] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2022-02-22 01:14:36.668762: I tensorflow/core/platform/profile_utils/cpu_utils.cc:102] CPU Frequency: 3500000000 Hz
# 2022-02-22 01:14:36.669753: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x7f2c74000b60 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2022-02-22 01:14:36.669773: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version

# %% [markdown]
# We will compile the model with the sparse categorical cross-entropy loss and the ADAM optimizer.

# %%
model.compile(
    optimizer="adam", 
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"]
)

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# INPUT (InputLayer)           [(None, 28, 28, 1)]       0
# _________________________________________________________________
# C1 (Conv2D)                  (None, 24, 24, 6)         156
# _________________________________________________________________
# S1 (MaxPooling2D)            (None, 12, 12, 6)         0
# _________________________________________________________________
# C3 (Conv2D)                  (None, 8, 8, 16)          2416
# _________________________________________________________________
# S4 (MaxPooling2D)            (None, 4, 4, 16)          0
# _________________________________________________________________
# FLATTEN (Flatten)            (None, 256)               0
# _________________________________________________________________
# F5 (Dense)                   (None, 120)               30840
# _________________________________________________________________
# F6 (Dense)                   (None, 84)                10164
# _________________________________________________________________
# OUTPUT (Dense)               (None, 10)                850
# =================================================================
# Total params: 44,426
# Trainable params: 44,426
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Now we can start training!

# %%
# Start training loop
train_loss = []
train_acc = []
test_acc = []
for i in range(epochs):
    rand_index = np.random.choice(len(x_train), size=batch_size)
    rand_x = x_train[rand_index]
    rand_y = y_train[rand_index]
    
    history_train = model.train_on_batch(rand_x, rand_y)
    
    if (i+1) % eval_every == 0:
        eval_index = np.random.choice(len(x_test), size=evaluation_size)
        eval_x = x_test[eval_index]
        eval_y = y_test[eval_index]
        
        history_eval = model.evaluate(eval_x,eval_y)
        
        # Record and print results
        train_loss.append(history_train[0])
        train_acc.append(history_train[1])
        test_acc.append(history_eval[1])
        acc_and_loss = [(i+1), history_train[0], history_train[1], history_eval[1]]
        acc_and_loss = [np.round(x,2) for x in acc_and_loss]
        print('Epoch # {}. Train Loss: {:.2f}. Train Acc (Test Acc): {:.2f} ({:.2f})'.format(*acc_and_loss))
# Out:
# 16/16 [==============================] - 0s 3ms/step - loss: 2.1950 - accuracy: 0.3100
# Epoch # 5. Train Loss: 2.21. Train Acc (Test Acc): 0.23 (0.31)
# 16/16 [==============================] - 0s 3ms/step - loss: 2.0484 - accuracy: 0.4880
# Epoch # 10. Train Loss: 2.08. Train Acc (Test Acc): 0.47 (0.49)
# 16/16 [==============================] - 0s 4ms/step - loss: 1.7417 - accuracy: 0.7020
# Epoch # 15. Train Loss: 1.84. Train Acc (Test Acc): 0.64 (0.70)
# 16/16 [==============================] - 0s 4ms/step - loss: 1.3469 - accuracy: 0.7400
# Epoch # 20. Train Loss: 1.47. Train Acc (Test Acc): 0.71 (0.74)
# 16/16 [==============================] - 0s 4ms/step - loss: 0.9640 - accuracy: 0.8100
# Epoch # 25. Train Loss: 1.10. Train Acc (Test Acc): 0.80 (0.81)
# 16/16 [==============================] - 0s 4ms/step - loss: 0.7149 - accuracy: 0.8120
# Epoch # 30. Train Loss: 0.91. Train Acc (Test Acc): 0.75 (0.81)
# 16/16 [==============================] - 0s 3ms/step - loss: 0.5681 - accuracy: 0.8380
# Epoch # 35. Train Loss: 0.66. Train Acc (Test Acc): 0.79 (0.84)
# 16/16 [==============================] - 0s 5ms/step - loss: 0.5454 - accuracy: 0.8020
# Epoch # 40. Train Loss: 0.52. Train Acc (Test Acc): 0.90 (0.80)
# 16/16 [==============================] - 0s 4ms/step - loss: 0.4935 - accuracy: 0.8700
# Epoch # 45. Train Loss: 0.58. Train Acc (Test Acc): 0.82 (0.87)
# 16/16 [==============================] - 0s 4ms/step - loss: 0.4270 - accuracy: 0.8640
# Epoch # 50. Train Loss: 0.45. Train Acc (Test Acc): 0.84 (0.86)
# 16/16 [==============================] - 0s 3ms/step - loss: 0.3874 - accuracy: 0.8820
# Epoch # 55. Train Loss: 0.38. Train Acc (Test Acc): 0.86 (0.88)
# 16/16 [==============================] - 0s 4ms/step - loss: 0.3856 - accuracy: 0.8740
# Epoch # 60. Train Loss: 0.37. Train Acc (Test Acc): 0.91 (0.87)
# 16/16 [==============================] - 0s 4ms/step - loss: 0.4399 - accuracy: 0.8520
# Epoch # 65. Train Loss: 0.41. Train Acc (Test Acc): 0.88 (0.85)
# 16/16 [==============================] - 0s 3ms/step - loss: 0.4184 - accuracy: 0.8840
# Epoch # 70. Train Loss: 0.53. Train Acc (Test Acc): 0.87 (0.88)
# 16/16 [==============================] - 0s 4ms/step - loss: 0.3599 - accuracy: 0.9120
# Epoch # 75. Train Loss: 0.40. Train Acc (Test Acc): 0.90 (0.91)
# 16/16 [==============================] - 0s 4ms/step - loss: 0.3028 - accuracy: 0.8940
# Epoch # 80. Train Loss: 0.49. Train Acc (Test Acc): 0.86 (0.89)
# 16/16 [==============================] - 0s 4ms/step - loss: 0.3839 - accuracy: 0.8940
# Epoch # 85. Train Loss: 0.34. Train Acc (Test Acc): 0.91 (0.89)
# 16/16 [==============================] - 0s 4ms/step - loss: 0.3153 - accuracy: 0.9160
# Epoch # 90. Train Loss: 0.44. Train Acc (Test Acc): 0.85 (0.92)
# 16/16 [==============================] - 0s 4ms/step - loss: 0.3027 - accuracy: 0.9200
# Epoch # 95. Train Loss: 0.30. Train Acc (Test Acc): 0.88 (0.92)
# 16/16 [==============================] - 0s 4ms/step - loss: 0.2881 - accuracy: 0.9180
# Epoch # 100. Train Loss: 0.21. Train Acc (Test Acc): 0.97 (0.92)
# 16/16 [==============================] - 0s 4ms/step - loss: 0.3237 - accuracy: 0.9000
# Epoch # 105. Train Loss: 0.20. Train Acc (Test Acc): 0.91 (0.90)
# 16/16 [==============================] - 0s 4ms/step - loss: 0.2739 - accuracy: 0.9120
# Epoch # 110. Train Loss: 0.39. Train Acc (Test Acc): 0.86 (0.91)
# 16/16 [==============================] - 0s 3ms/step - loss: 0.1948 - accuracy: 0.9440
# Epoch # 115. Train Loss: 0.26. Train Acc (Test Acc): 0.90 (0.94)
# 16/16 [==============================] - 0s 3ms/step - loss: 0.3223 - accuracy: 0.9100
# Epoch # 120. Train Loss: 0.49. Train Acc (Test Acc): 0.88 (0.91)
# 16/16 [==============================] - 0s 3ms/step - loss: 0.2925 - accuracy: 0.9100
# Epoch # 125. Train Loss: 0.20. Train Acc (Test Acc): 0.94 (0.91)
# 16/16 [==============================] - 0s 3ms/step - loss: 0.2087 - accuracy: 0.9300
# Epoch # 130. Train Loss: 0.26. Train Acc (Test Acc): 0.93 (0.93)
# 16/16 [==============================] - 0s 5ms/step - loss: 0.2789 - accuracy: 0.9180
# Epoch # 135. Train Loss: 0.17. Train Acc (Test Acc): 0.94 (0.92)
# 16/16 [==============================] - 0s 4ms/step - loss: 0.2967 - accuracy: 0.9060
# Epoch # 140. Train Loss: 0.24. Train Acc (Test Acc): 0.92 (0.91)
# 16/16 [==============================] - 0s 4ms/step - loss: 0.2524 - accuracy: 0.9200
# Epoch # 145. Train Loss: 0.33. Train Acc (Test Acc): 0.88 (0.92)
# 16/16 [==============================] - 0s 4ms/step - loss: 0.2344 - accuracy: 0.9360
# Epoch # 150. Train Loss: 0.29. Train Acc (Test Acc): 0.91 (0.94)
# 16/16 [==============================] - 0s 4ms/step - loss: 0.2565 - accuracy: 0.9100
# Epoch # 155. Train Loss: 0.46. Train Acc (Test Acc): 0.87 (0.91)
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1936 - accuracy: 0.9500
# Epoch # 160. Train Loss: 0.23. Train Acc (Test Acc): 0.94 (0.95)
# 16/16 [==============================] - 0s 4ms/step - loss: 0.2173 - accuracy: 0.9500
# Epoch # 165. Train Loss: 0.18. Train Acc (Test Acc): 0.94 (0.95)
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1828 - accuracy: 0.9460
# Epoch # 170. Train Loss: 0.33. Train Acc (Test Acc): 0.91 (0.95)
# 16/16 [==============================] - 0s 4ms/step - loss: 0.2268 - accuracy: 0.9420
# Epoch # 175. Train Loss: 0.27. Train Acc (Test Acc): 0.91 (0.94)
# 16/16 [==============================] - 0s 5ms/step - loss: 0.1876 - accuracy: 0.9620
# Epoch # 180. Train Loss: 0.26. Train Acc (Test Acc): 0.95 (0.96)
# 16/16 [==============================] - 0s 7ms/step - loss: 0.1692 - accuracy: 0.9480
# Epoch # 185. Train Loss: 0.24. Train Acc (Test Acc): 0.90 (0.95)
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1977 - accuracy: 0.9460
# Epoch # 190. Train Loss: 0.35. Train Acc (Test Acc): 0.88 (0.95)
# 16/16 [==============================] - 0s 5ms/step - loss: 0.1830 - accuracy: 0.9440
# Epoch # 195. Train Loss: 0.23. Train Acc (Test Acc): 0.95 (0.94)
# 16/16 [==============================] - 0s 6ms/step - loss: 0.2081 - accuracy: 0.9280
# Epoch # 200. Train Loss: 0.31. Train Acc (Test Acc): 0.88 (0.93)
# 16/16 [==============================] - 0s 4ms/step - loss: 0.2561 - accuracy: 0.9120
# Epoch # 205. Train Loss: 0.18. Train Acc (Test Acc): 0.95 (0.91)
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1914 - accuracy: 0.9540
# Epoch # 210. Train Loss: 0.11. Train Acc (Test Acc): 0.98 (0.95)
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1947 - accuracy: 0.9420
# Epoch # 215. Train Loss: 0.34. Train Acc (Test Acc): 0.93 (0.94)
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1596 - accuracy: 0.9480
# Epoch # 220. Train Loss: 0.16. Train Acc (Test Acc): 0.92 (0.95)
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1882 - accuracy: 0.9380
# Epoch # 225. Train Loss: 0.18. Train Acc (Test Acc): 0.94 (0.94)
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1760 - accuracy: 0.9460
# Epoch # 230. Train Loss: 0.24. Train Acc (Test Acc): 0.91 (0.95)
# 16/16 [==============================] - 0s 4ms/step - loss: 0.2044 - accuracy: 0.9500
# Epoch # 235. Train Loss: 0.23. Train Acc (Test Acc): 0.95 (0.95)
# 16/16 [==============================] - 0s 5ms/step - loss: 0.1718 - accuracy: 0.9480
# Epoch # 240. Train Loss: 0.22. Train Acc (Test Acc): 0.94 (0.95)
# 16/16 [==============================] - 0s 6ms/step - loss: 0.1565 - accuracy: 0.9500
# Epoch # 245. Train Loss: 0.15. Train Acc (Test Acc): 0.96 (0.95)
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1884 - accuracy: 0.9560
# Epoch # 250. Train Loss: 0.31. Train Acc (Test Acc): 0.92 (0.96)
# 16/16 [==============================] - 0s 4ms/step - loss: 0.2079 - accuracy: 0.9380
# Epoch # 255. Train Loss: 0.10. Train Acc (Test Acc): 0.98 (0.94)
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1686 - accuracy: 0.9440
# Epoch # 260. Train Loss: 0.14. Train Acc (Test Acc): 0.96 (0.94)
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1588 - accuracy: 0.9480
# Epoch # 265. Train Loss: 0.22. Train Acc (Test Acc): 0.93 (0.95)
# 16/16 [==============================] - 0s 5ms/step - loss: 0.1621 - accuracy: 0.9520
# Epoch # 270. Train Loss: 0.26. Train Acc (Test Acc): 0.93 (0.95)
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1663 - accuracy: 0.9580
# Epoch # 275. Train Loss: 0.25. Train Acc (Test Acc): 0.93 (0.96)
# 16/16 [==============================] - 0s 6ms/step - loss: 0.1539 - accuracy: 0.9560
# Epoch # 280. Train Loss: 0.11. Train Acc (Test Acc): 0.98 (0.96)
# 16/16 [==============================] - 0s 5ms/step - loss: 0.1697 - accuracy: 0.9420
# Epoch # 285. Train Loss: 0.17. Train Acc (Test Acc): 0.97 (0.94)
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1756 - accuracy: 0.9500
# Epoch # 290. Train Loss: 0.18. Train Acc (Test Acc): 0.95 (0.95)
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1608 - accuracy: 0.9580
# Epoch # 295. Train Loss: 0.12. Train Acc (Test Acc): 0.97 (0.96)
# 16/16 [==============================] - 0s 5ms/step - loss: 0.1410 - accuracy: 0.9660
# Epoch # 300. Train Loss: 0.17. Train Acc (Test Acc): 0.95 (0.97)
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1679 - accuracy: 0.9600
# Epoch # 305. Train Loss: 0.12. Train Acc (Test Acc): 0.97 (0.96)
# 16/16 [==============================] - 0s 5ms/step - loss: 0.1459 - accuracy: 0.9500
# Epoch # 310. Train Loss: 0.23. Train Acc (Test Acc): 0.91 (0.95)
# 16/16 [==============================] - 0s 5ms/step - loss: 0.1732 - accuracy: 0.9400
# Epoch # 315. Train Loss: 0.10. Train Acc (Test Acc): 0.98 (0.94)
# 16/16 [==============================] - 0s 5ms/step - loss: 0.1551 - accuracy: 0.9480
# Epoch # 320. Train Loss: 0.10. Train Acc (Test Acc): 0.98 (0.95)
# 16/16 [==============================] - 0s 5ms/step - loss: 0.1380 - accuracy: 0.9500
# Epoch # 325. Train Loss: 0.09. Train Acc (Test Acc): 0.98 (0.95)
# 16/16 [==============================] - 0s 5ms/step - loss: 0.2075 - accuracy: 0.9400
# Epoch # 330. Train Loss: 0.13. Train Acc (Test Acc): 0.95 (0.94)
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1444 - accuracy: 0.9640
# Epoch # 335. Train Loss: 0.13. Train Acc (Test Acc): 0.97 (0.96)
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1457 - accuracy: 0.9500
# Epoch # 340. Train Loss: 0.15. Train Acc (Test Acc): 0.97 (0.95)
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1215 - accuracy: 0.9740
# Epoch # 345. Train Loss: 0.06. Train Acc (Test Acc): 0.99 (0.97)
# 16/16 [==============================] - 0s 12ms/step - loss: 0.1320 - accuracy: 0.9680
# Epoch # 350. Train Loss: 0.09. Train Acc (Test Acc): 0.96 (0.97)
# 16/16 [==============================] - 0s 6ms/step - loss: 0.1367 - accuracy: 0.9600
# Epoch # 355. Train Loss: 0.20. Train Acc (Test Acc): 0.95 (0.96)
# 16/16 [==============================] - 0s 8ms/step - loss: 0.1919 - accuracy: 0.9340
# Epoch # 360. Train Loss: 0.14. Train Acc (Test Acc): 0.93 (0.93)
# 16/16 [==============================] - 0s 5ms/step - loss: 0.1159 - accuracy: 0.9640
# Epoch # 365. Train Loss: 0.18. Train Acc (Test Acc): 0.95 (0.96)
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1340 - accuracy: 0.9640
# Epoch # 370. Train Loss: 0.07. Train Acc (Test Acc): 0.98 (0.96)
# 16/16 [==============================] - 0s 5ms/step - loss: 0.1199 - accuracy: 0.9640
# Epoch # 375. Train Loss: 0.18. Train Acc (Test Acc): 0.97 (0.96)
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1124 - accuracy: 0.9600
# Epoch # 380. Train Loss: 0.13. Train Acc (Test Acc): 0.97 (0.96)
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0930 - accuracy: 0.9700
# Epoch # 385. Train Loss: 0.16. Train Acc (Test Acc): 0.95 (0.97)
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1101 - accuracy: 0.9660
# Epoch # 390. Train Loss: 0.13. Train Acc (Test Acc): 0.96 (0.97)
# 16/16 [==============================] - 0s 3ms/step - loss: 0.1347 - accuracy: 0.9600
# Epoch # 395. Train Loss: 0.13. Train Acc (Test Acc): 0.96 (0.96)
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0994 - accuracy: 0.9660
# Epoch # 400. Train Loss: 0.15. Train Acc (Test Acc): 0.95 (0.97)
# 16/16 [==============================] - 0s 7ms/step - loss: 0.1348 - accuracy: 0.9460
# Epoch # 405. Train Loss: 0.26. Train Acc (Test Acc): 0.97 (0.95)
# 16/16 [==============================] - 0s 5ms/step - loss: 0.1699 - accuracy: 0.9460
# Epoch # 410. Train Loss: 0.10. Train Acc (Test Acc): 0.97 (0.95)
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1387 - accuracy: 0.9580
# Epoch # 415. Train Loss: 0.07. Train Acc (Test Acc): 0.98 (0.96)
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0929 - accuracy: 0.9740
# Epoch # 420. Train Loss: 0.08. Train Acc (Test Acc): 0.97 (0.97)
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1042 - accuracy: 0.9680
# Epoch # 425. Train Loss: 0.11. Train Acc (Test Acc): 0.97 (0.97)
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1445 - accuracy: 0.9540
# Epoch # 430. Train Loss: 0.24. Train Acc (Test Acc): 0.96 (0.95)
# 16/16 [==============================] - 0s 5ms/step - loss: 0.0812 - accuracy: 0.9680
# Epoch # 435. Train Loss: 0.06. Train Acc (Test Acc): 0.98 (0.97)
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1430 - accuracy: 0.9560
# Epoch # 440. Train Loss: 0.10. Train Acc (Test Acc): 0.97 (0.96)
# 16/16 [==============================] - 0s 5ms/step - loss: 0.1248 - accuracy: 0.9600
# Epoch # 445. Train Loss: 0.06. Train Acc (Test Acc): 0.99 (0.96)
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1128 - accuracy: 0.9600
# Epoch # 450. Train Loss: 0.14. Train Acc (Test Acc): 0.94 (0.96)
# 16/16 [==============================] - 0s 5ms/step - loss: 0.1557 - accuracy: 0.9480
# Epoch # 455. Train Loss: 0.13. Train Acc (Test Acc): 0.97 (0.95)
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0770 - accuracy: 0.9760
# Epoch # 460. Train Loss: 0.15. Train Acc (Test Acc): 0.95 (0.98)
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1479 - accuracy: 0.9560
# Epoch # 465. Train Loss: 0.22. Train Acc (Test Acc): 0.95 (0.96)
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0965 - accuracy: 0.9700
# Epoch # 470. Train Loss: 0.14. Train Acc (Test Acc): 0.95 (0.97)
# 16/16 [==============================] - 0s 5ms/step - loss: 0.1232 - accuracy: 0.9580
# Epoch # 475. Train Loss: 0.08. Train Acc (Test Acc): 0.97 (0.96)
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1175 - accuracy: 0.9640
# Epoch # 480. Train Loss: 0.07. Train Acc (Test Acc): 0.98 (0.96)
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1177 - accuracy: 0.9620
# Epoch # 485. Train Loss: 0.09. Train Acc (Test Acc): 0.97 (0.96)
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0784 - accuracy: 0.9800
# Epoch # 490. Train Loss: 0.06. Train Acc (Test Acc): 0.99 (0.98)
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0954 - accuracy: 0.9640
# Epoch # 495. Train Loss: 0.24. Train Acc (Test Acc): 0.96 (0.96)
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1366 - accuracy: 0.9600
# Epoch # 500. Train Loss: 0.06. Train Acc (Test Acc): 0.99 (0.96)
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1132 - accuracy: 0.9680
# Epoch # 505. Train Loss: 0.08. Train Acc (Test Acc): 0.98 (0.97)
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0956 - accuracy: 0.9720
# Epoch # 510. Train Loss: 0.15. Train Acc (Test Acc): 0.94 (0.97)
# 16/16 [==============================] - 0s 5ms/step - loss: 0.0949 - accuracy: 0.9700
# Epoch # 515. Train Loss: 0.10. Train Acc (Test Acc): 0.97 (0.97)
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0900 - accuracy: 0.9700
# Epoch # 520. Train Loss: 0.16. Train Acc (Test Acc): 0.95 (0.97)
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0900 - accuracy: 0.9780
# Epoch # 525. Train Loss: 0.07. Train Acc (Test Acc): 0.98 (0.98)
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0998 - accuracy: 0.9740
# Epoch # 530. Train Loss: 0.12. Train Acc (Test Acc): 0.96 (0.97)
# 16/16 [==============================] - 0s 5ms/step - loss: 0.0587 - accuracy: 0.9820
# Epoch # 535. Train Loss: 0.11. Train Acc (Test Acc): 0.96 (0.98)
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0903 - accuracy: 0.9720
# Epoch # 540. Train Loss: 0.08. Train Acc (Test Acc): 0.98 (0.97)
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1360 - accuracy: 0.9520
# Epoch # 545. Train Loss: 0.18. Train Acc (Test Acc): 0.94 (0.95)
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1119 - accuracy: 0.9520
# Epoch # 550. Train Loss: 0.18. Train Acc (Test Acc): 0.93 (0.95)
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0959 - accuracy: 0.9720
# Epoch # 555. Train Loss: 0.16. Train Acc (Test Acc): 0.94 (0.97)
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1229 - accuracy: 0.9640
# Epoch # 560. Train Loss: 0.13. Train Acc (Test Acc): 0.97 (0.96)
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0947 - accuracy: 0.9780
# Epoch # 565. Train Loss: 0.17. Train Acc (Test Acc): 0.96 (0.98)
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0947 - accuracy: 0.9800
# Epoch # 570. Train Loss: 0.20. Train Acc (Test Acc): 0.94 (0.98)
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1188 - accuracy: 0.9680
# Epoch # 575. Train Loss: 0.08. Train Acc (Test Acc): 0.98 (0.97)
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1108 - accuracy: 0.9760
# Epoch # 580. Train Loss: 0.09. Train Acc (Test Acc): 0.95 (0.98)
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0944 - accuracy: 0.9740
# Epoch # 585. Train Loss: 0.05. Train Acc (Test Acc): 1.00 (0.97)
# 16/16 [==============================] - 0s 5ms/step - loss: 0.1104 - accuracy: 0.9760
# Epoch # 590. Train Loss: 0.15. Train Acc (Test Acc): 0.95 (0.98)
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1250 - accuracy: 0.9540
# Epoch # 595. Train Loss: 0.09. Train Acc (Test Acc): 0.98 (0.95)
# 16/16 [==============================] - 0s 3ms/step - loss: 0.1278 - accuracy: 0.9560
# Epoch # 600. Train Loss: 0.04. Train Acc (Test Acc): 0.99 (0.96)
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0871 - accuracy: 0.9800
# Epoch # 605. Train Loss: 0.03. Train Acc (Test Acc): 0.99 (0.98)
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1190 - accuracy: 0.9560
# Epoch # 610. Train Loss: 0.06. Train Acc (Test Acc): 0.98 (0.96)
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0527 - accuracy: 0.9840
# Epoch # 615. Train Loss: 0.15. Train Acc (Test Acc): 0.96 (0.98)
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0825 - accuracy: 0.9700
# Epoch # 620. Train Loss: 0.15. Train Acc (Test Acc): 0.96 (0.97)
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1002 - accuracy: 0.9660
# Epoch # 625. Train Loss: 0.07. Train Acc (Test Acc): 0.97 (0.97)
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0853 - accuracy: 0.9740
# Epoch # 630. Train Loss: 0.12. Train Acc (Test Acc): 0.94 (0.97)
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1085 - accuracy: 0.9580
# Epoch # 635. Train Loss: 0.09. Train Acc (Test Acc): 0.98 (0.96)
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1321 - accuracy: 0.9620
# Epoch # 640. Train Loss: 0.10. Train Acc (Test Acc): 0.97 (0.96)
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1021 - accuracy: 0.9640
# Epoch # 645. Train Loss: 0.09. Train Acc (Test Acc): 0.98 (0.96)
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0765 - accuracy: 0.9800
# Epoch # 650. Train Loss: 0.06. Train Acc (Test Acc): 0.98 (0.98)
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1395 - accuracy: 0.9480
# Epoch # 655. Train Loss: 0.07. Train Acc (Test Acc): 0.99 (0.95)
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0636 - accuracy: 0.9780
# Epoch # 660. Train Loss: 0.13. Train Acc (Test Acc): 0.98 (0.98)
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1188 - accuracy: 0.9640
# Epoch # 665. Train Loss: 0.15. Train Acc (Test Acc): 0.98 (0.96)
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1290 - accuracy: 0.9580
# Epoch # 670. Train Loss: 0.08. Train Acc (Test Acc): 0.99 (0.96)
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0680 - accuracy: 0.9780
# Epoch # 675. Train Loss: 0.19. Train Acc (Test Acc): 0.96 (0.98)
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0800 - accuracy: 0.9840
# Epoch # 680. Train Loss: 0.07. Train Acc (Test Acc): 0.98 (0.98)
# 16/16 [==============================] - 0s 5ms/step - loss: 0.0844 - accuracy: 0.9740
# Epoch # 685. Train Loss: 0.06. Train Acc (Test Acc): 0.98 (0.97)
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0473 - accuracy: 0.9880
# Epoch # 690. Train Loss: 0.08. Train Acc (Test Acc): 0.97 (0.99)
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0400 - accuracy: 0.9860
# Epoch # 695. Train Loss: 0.02. Train Acc (Test Acc): 1.00 (0.99)
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1048 - accuracy: 0.9640
# Epoch # 700. Train Loss: 0.10. Train Acc (Test Acc): 0.98 (0.96)
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1264 - accuracy: 0.9680
# Epoch # 705. Train Loss: 0.09. Train Acc (Test Acc): 0.97 (0.97)
# 16/16 [==============================] - 0s 5ms/step - loss: 0.0779 - accuracy: 0.9800
# Epoch # 710. Train Loss: 0.05. Train Acc (Test Acc): 0.99 (0.98)
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1046 - accuracy: 0.9720
# Epoch # 715. Train Loss: 0.10. Train Acc (Test Acc): 0.97 (0.97)
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0909 - accuracy: 0.9760
# Epoch # 720. Train Loss: 0.04. Train Acc (Test Acc): 0.99 (0.98)
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0898 - accuracy: 0.9780
# Epoch # 725. Train Loss: 0.12. Train Acc (Test Acc): 0.96 (0.98)
# 16/16 [==============================] - 0s 5ms/step - loss: 0.0745 - accuracy: 0.9660
# Epoch # 730. Train Loss: 0.12. Train Acc (Test Acc): 0.95 (0.97)
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0816 - accuracy: 0.9680
# Epoch # 735. Train Loss: 0.10. Train Acc (Test Acc): 0.98 (0.97)
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0787 - accuracy: 0.9680
# Epoch # 740. Train Loss: 0.08. Train Acc (Test Acc): 0.99 (0.97)
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1034 - accuracy: 0.9640
# Epoch # 745. Train Loss: 0.06. Train Acc (Test Acc): 0.99 (0.96)
# 16/16 [==============================] - 0s 5ms/step - loss: 0.0820 - accuracy: 0.9740
# Epoch # 750. Train Loss: 0.10. Train Acc (Test Acc): 0.96 (0.97)
# 16/16 [==============================] - 0s 5ms/step - loss: 0.0637 - accuracy: 0.9840
# Epoch # 755. Train Loss: 0.02. Train Acc (Test Acc): 1.00 (0.98)
# 16/16 [==============================] - 0s 5ms/step - loss: 0.0721 - accuracy: 0.9800
# Epoch # 760. Train Loss: 0.05. Train Acc (Test Acc): 0.98 (0.98)
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0680 - accuracy: 0.9760
# Epoch # 765. Train Loss: 0.16. Train Acc (Test Acc): 0.97 (0.98)
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0748 - accuracy: 0.9700
# Epoch # 770. Train Loss: 0.08. Train Acc (Test Acc): 0.98 (0.97)
# 16/16 [==============================] - 0s 5ms/step - loss: 0.0796 - accuracy: 0.9700
# Epoch # 775. Train Loss: 0.21. Train Acc (Test Acc): 0.94 (0.97)
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0574 - accuracy: 0.9740
# Epoch # 780. Train Loss: 0.12. Train Acc (Test Acc): 0.97 (0.97)
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0583 - accuracy: 0.9800
# Epoch # 785. Train Loss: 0.05. Train Acc (Test Acc): 0.99 (0.98)
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1312 - accuracy: 0.9440
# Epoch # 790. Train Loss: 0.02. Train Acc (Test Acc): 1.00 (0.94)
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0492 - accuracy: 0.9820
# Epoch # 795. Train Loss: 0.09. Train Acc (Test Acc): 0.96 (0.98)
# 16/16 [==============================] - 0s 5ms/step - loss: 0.0744 - accuracy: 0.9760
# Epoch # 800. Train Loss: 0.07. Train Acc (Test Acc): 0.96 (0.98)
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0622 - accuracy: 0.9780
# Epoch # 805. Train Loss: 0.04. Train Acc (Test Acc): 0.99 (0.98)
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0762 - accuracy: 0.9880
# Epoch # 810. Train Loss: 0.06. Train Acc (Test Acc): 0.98 (0.99)
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0987 - accuracy: 0.9680
# Epoch # 815. Train Loss: 0.02. Train Acc (Test Acc): 0.99 (0.97)
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0725 - accuracy: 0.9700
# Epoch # 820. Train Loss: 0.15. Train Acc (Test Acc): 0.94 (0.97)
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0412 - accuracy: 0.9840
# Epoch # 825. Train Loss: 0.13. Train Acc (Test Acc): 0.96 (0.98)
# 16/16 [==============================] - 0s 5ms/step - loss: 0.0764 - accuracy: 0.9800
# Epoch # 830. Train Loss: 0.02. Train Acc (Test Acc): 1.00 (0.98)
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1025 - accuracy: 0.9620
# Epoch # 835. Train Loss: 0.07. Train Acc (Test Acc): 0.97 (0.96)
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0630 - accuracy: 0.9740
# Epoch # 840. Train Loss: 0.04. Train Acc (Test Acc): 0.98 (0.97)
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0713 - accuracy: 0.9740
# Epoch # 845. Train Loss: 0.04. Train Acc (Test Acc): 0.97 (0.97)
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0769 - accuracy: 0.9760
# Epoch # 850. Train Loss: 0.05. Train Acc (Test Acc): 0.97 (0.98)
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0578 - accuracy: 0.9820
# Epoch # 855. Train Loss: 0.03. Train Acc (Test Acc): 1.00 (0.98)
# 16/16 [==============================] - 0s 7ms/step - loss: 0.1212 - accuracy: 0.9660
# Epoch # 860. Train Loss: 0.10. Train Acc (Test Acc): 0.97 (0.97)
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0758 - accuracy: 0.9780
# Epoch # 865. Train Loss: 0.05. Train Acc (Test Acc): 0.98 (0.98)
# 16/16 [==============================] - 0s 5ms/step - loss: 0.0667 - accuracy: 0.9840
# Epoch # 870. Train Loss: 0.11. Train Acc (Test Acc): 0.95 (0.98)
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0743 - accuracy: 0.9760
# Epoch # 875. Train Loss: 0.11. Train Acc (Test Acc): 0.98 (0.98)
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0781 - accuracy: 0.9640
# Epoch # 880. Train Loss: 0.04. Train Acc (Test Acc): 1.00 (0.96)
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0778 - accuracy: 0.9800
# Epoch # 885. Train Loss: 0.13. Train Acc (Test Acc): 0.96 (0.98)
# 16/16 [==============================] - 0s 10ms/step - loss: 0.0775 - accuracy: 0.9760
# Epoch # 890. Train Loss: 0.04. Train Acc (Test Acc): 1.00 (0.98)
# 16/16 [==============================] - 0s 5ms/step - loss: 0.1002 - accuracy: 0.9720
# Epoch # 895. Train Loss: 0.14. Train Acc (Test Acc): 0.95 (0.97)
# 16/16 [==============================] - 0s 5ms/step - loss: 0.0632 - accuracy: 0.9860
# Epoch # 900. Train Loss: 0.04. Train Acc (Test Acc): 0.99 (0.99)
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0875 - accuracy: 0.9680
# Epoch # 905. Train Loss: 0.04. Train Acc (Test Acc): 1.00 (0.97)
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0618 - accuracy: 0.9840
# Epoch # 910. Train Loss: 0.09. Train Acc (Test Acc): 0.97 (0.98)
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0943 - accuracy: 0.9720
# Epoch # 915. Train Loss: 0.12. Train Acc (Test Acc): 0.97 (0.97)
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0606 - accuracy: 0.9780
# Epoch # 920. Train Loss: 0.03. Train Acc (Test Acc): 1.00 (0.98)
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0640 - accuracy: 0.9820
# Epoch # 925. Train Loss: 0.05. Train Acc (Test Acc): 0.98 (0.98)
# 16/16 [==============================] - 0s 5ms/step - loss: 0.0946 - accuracy: 0.9720
# Epoch # 930. Train Loss: 0.04. Train Acc (Test Acc): 0.99 (0.97)
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0885 - accuracy: 0.9760
# Epoch # 935. Train Loss: 0.04. Train Acc (Test Acc): 0.97 (0.98)
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0755 - accuracy: 0.9820
# Epoch # 940. Train Loss: 0.05. Train Acc (Test Acc): 0.98 (0.98)
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0546 - accuracy: 0.9800
# Epoch # 945. Train Loss: 0.03. Train Acc (Test Acc): 1.00 (0.98)
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0642 - accuracy: 0.9800
# Epoch # 950. Train Loss: 0.07. Train Acc (Test Acc): 0.98 (0.98)
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0675 - accuracy: 0.9720
# Epoch # 955. Train Loss: 0.02. Train Acc (Test Acc): 0.99 (0.97)
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0626 - accuracy: 0.9720
# Epoch # 960. Train Loss: 0.05. Train Acc (Test Acc): 0.97 (0.97)
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0698 - accuracy: 0.9840
# Epoch # 965. Train Loss: 0.07. Train Acc (Test Acc): 0.96 (0.98)
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0612 - accuracy: 0.9800
# Epoch # 970. Train Loss: 0.09. Train Acc (Test Acc): 0.97 (0.98)
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1124 - accuracy: 0.9720
# Epoch # 975. Train Loss: 0.06. Train Acc (Test Acc): 0.97 (0.97)
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0557 - accuracy: 0.9820
# Epoch # 980. Train Loss: 0.04. Train Acc (Test Acc): 0.99 (0.98)
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0677 - accuracy: 0.9820
# Epoch # 985. Train Loss: 0.06. Train Acc (Test Acc): 0.98 (0.98)
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0416 - accuracy: 0.9820
# Epoch # 990. Train Loss: 0.12. Train Acc (Test Acc): 0.98 (0.98)
# 16/16 [==============================] - 0s 5ms/step - loss: 0.0666 - accuracy: 0.9800
# Epoch # 995. Train Loss: 0.07. Train Acc (Test Acc): 0.98 (0.98)
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0779 - accuracy: 0.9840
# Epoch # 1000. Train Loss: 0.03. Train Acc (Test Acc): 0.99 (0.98)

# %%
history_train[0]
# Out:
# 0.029403138905763626

# %% [markdown]
# Let's plot the loss and accuracy.

# %%
# Matlotlib code to plot the loss and accuracy
eval_indices = range(0, epochs, eval_every)
# Plot loss over time
plt.plot(eval_indices, train_loss, 'k-')
plt.title('Loss per Epoch')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.show()

# Plot train and test accuracy
plt.plot(eval_indices, train_acc, 'k-', label='Train Set Accuracy')
plt.plot(eval_indices, test_acc, 'r--', label='Test Set Accuracy')
plt.title('Train and Test Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')
plt.show()

# %% [markdown]
# Let's see how our model runs on 6 examples.

# %%
# Plot some samples and their predictions
actuals = y_test[36:42]
preds = model.predict(x_test[36:42])
predictions = np.argmax(preds,axis=1)
images = np.squeeze(x_test[36:42])

Nrows = 2
Ncols = 3
for i in range(6):
    plt.subplot(Nrows, Ncols, i+1)
    plt.imshow(np.reshape(images[i], [28,28]), cmap='Greys_r')
    plt.title('Actual: ' + str(actuals[i]) + ' Pred: ' + str(predictions[i]),
                               fontsize=10)
    frame = plt.gca()
    frame.axes.get_xaxis().set_visible(False)
    frame.axes.get_yaxis().set_visible(False)

plt.show()

# %%
import tensorflowjs as tfjs
import time

today = time.strftime("%Y-%m-%d")
tfjs.converters.save_keras_model(model, f"../../models/{today}")
